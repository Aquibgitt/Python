# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Introduction - Data Type
# ```
# 1. What is your name : "ABC M"; "Aquib", "Bill" -- str
# 2. What is your first name: ABC; "Aquib"; "Bill"; 'J'   -- str
# 3. How many fruit/chocolate: 1; 5; -5                     -- int
# 4. What is the price of the fruit/chocolate: 3.50; 17.50; -- float
# 5. When did i purchase: 12-20-2025; 12-20-2025 09:20:.... -- str; date
#
# Where i write my code: Jupyter Notebook - Editor (client)
# -- Language: python
# -- Python Kernel(sever)
# ```

# %%
# A str in python can be created using single, double, triple quotes
print("What is your first name")
# print('what is your name')
# print("""what is your name""")
# Out:
# What is your first name

# %%
print("How many fruit/chocolate did you buy:")
no_of_chocolates = 5
# no_of_chocolates
print(no_of_chocolates)
print(f"The number of chcolates bought : {no_of_chocolates} ") # f - python3 formatting.
print(f"The number of chcolates bought : {no_of_chocolates * 3.50} ")
# Out:
# How many fruit/chocolate did you buy:
# 5
# The number of chcolates bought : 5
# The number of chcolates bought : 17.5

# %%
no_of_books=int(input("enter no of books:"))
print(f"the amount for your books is around,{no_of_books*5}")
# Out:
# enter no of books:5
# the amount for your books is around,25

# %% [markdown]
# ## Pizza Order and Receipt

# %% [markdown]
# ## Pizza Order and Receipt

# %% [markdown]
# ## UC1: Pizza Order and Receipt -- STATIC/Fixed/constant values

# %%
print("What type of Pizza(Small, Medium, Large")
type_pizza = "small"
pizza_price =  5
quantity = 3

print("#########Pizza Hut############")
print(f"Pizza purchaced: {type_pizza}")
print(f"price of pizza: {pizza_price}")
print(f"Number of pizza: {quantity}")
print(f"Total Cost: {pizza_price * quantity}")
print("#############################")
# Out:
# What type of Pizza(Small, Medium, Large
# #########Pizza Hut############
# Pizza purchaced: small
# price of pizza: 5
# Number of pizza: 3
# Total Cost: 15
# #############################

# %% [markdown]
# ##
# ```1. BUILT In - Functions:
# NOTE: functions have '()' - parenthesis.
#     print()
#     input() - interactively take input
#     type()  - know the datatype of variable
#     int(),float(),str(),...  - convert to an integer function
#
# ```
# ## 2. Arithematic operators
# - what we can do with numbers - what operations - CALCULATION/Processing/TRANSFORMATION

# %%
10 + 2
10 - 2
10 * 2
9 / 2 # Quotient as a float
9 % 2
9 // 2 # integer division
10 ** 2 # 10 to the power of 2
# Out:
# 12
# 8
# 20
# 4.5
# 1
# 4
# 100
# 8

# %% [markdown]
# ## Pizza Receipt - Dynamic/Runtime - interactive
# - type(5.25) # float. NOTE: type() is a function that tells the data type of the variable.

# %%
type_pizza = input("What type of Pizza(Small, Medium, Large: ")
type_pizza
pizza_price = input("Pizza Price: ")
pizza_price = int(pizza_price)                   # Convert Str to an integer
quantity = input("How many pizza(Quantity): ")
quantity = int(quantity)                         # Type casting - convert str to int

#type_pizza = "small"
#pizza_price =  5
#quantity = 3

print("#########Pizza Hut############")
print(f"Pizza purchaced: {type_pizza}")
print(f"price of pizza: {pizza_price}")
print(f"Number of pizza: {quantity}")
print(f"Total Cost: {pizza_price * quantity}")
print("#############################")
# Out:
# What type of Pizza(Small, Medium, Large:  small
# 'small'
# Pizza Price:  6
# How many pizza(Quantity):  3
# #########Pizza Hut############
# Pizza purchaced: small
# price of pizza: 6
# Number of pizza: 3
# Total Cost: 18
# #############################

# %% [markdown]
# ## Pizza_V2: Add additional logic for the Pizza Appplicaton:
# - What should be the FIXED price of s/m/l -- lookup/reference values.
# -   - small: 5
#     - medium: 8
#     - large: 10
# - Add toppings - Tomatos - 2, Olives - 1.5, mushrooms - 2.5

# %% [markdown]
# ## Conditional Statements
# - IF - ELIF - ELSE
# ```
# if condition is met:
#     perform statement1
#     perform statement2,...
# elif condition is met:
#     .....
# else:
#     perform statements - if above conditions are not met.
# ```
#
# ## Product Owner/Business User/Technical SME -- Business/Technical requirements

# %%
type_pizza = input("What type of Pizza(s), Medium(m), Large(l): ")
print(f"--->{type_pizza}")
# Lookup/Reference values -- eg. prices in a menu
if type_pizza == 's':
    pizza_price = 5
    print("The user wants small pizza")
elif type_pizza == 'm':
    pizza_price = 8
    print("The user wants medium pizza")
#elif type_pizza == 'l':
else:
    pizza_price = 10
    print("The user wants large pizza")

######## 2. Toppings - User can select ONE topping ############
#Add toppings - Tomatos - 2, Olives - 1.5, mushrooms - 2.5

topping = input("Do you need any TOPPINGS::Tomatos(t) - 2, Olives(o) - 1.5, mushrooms(m) - 2.5:")

# Lookup/Reference values -- eg. prices in a menu
if topping == 't':
    topping_price = 2
    print("The user wants Tomatos(t) topping pizza")
elif topping == 'o':
    topping_price = 1.5
    print("The user wants Olives(o) topping pizza")
else:
    topping_price = 2.5
    print("The user wants mushrooms(m) topping pizza")
#################################

quantity = int(input("How many pizza(Quantity): "))

print("#########Pizza Hut############")
print(f"Pizza purchaced: {type_pizza}")
print(f"price of pizza: {pizza_price}")
print(f"Number of pizza: {quantity}")
print(f"Total Cost: { (pizza_price + topping_price) * quantity}
print("#############################")
# Out:
# What type of Pizza(s), Medium(m), Large(l):  s
# --->s
# The user wants small pizza
# Do you need any TOPPINGS::Tomatos(t) - 2, Olives(o) - 1.5, mushrooms(m) - 2.5:  t
# The user wants Tomatos(t) topping pizza
# How many pizza(Quantity):  1
# #########Pizza Hut############
# Pizza purchaced: s
# price of pizza: 5
# Number of pizza: 1
# Total Cost: 7
# #############################
